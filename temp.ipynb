# %%
dir = '/home/disk1/dgt2021/DecomposedMetaNER_debug_3type/episode-data/inter/train_10_5.jsonl'
with open(dir, "r", encoding="utf-8") as json_file:
    json_list = list(json_file)

# %%
import json
json.dump(json.loads(json_list[0]), open('./temp.json', 'w', encoding='utf8'), indent=4, ensure_ascii=False)

# %%
json.loads(json_list[0])
# Out:
# {'support': {'word': [['it',
#     'was',
#     'first',
#     'seen',
#     'by',
#     'the',
#     'belgian',
#     'antarctic',
#     'expedition',
#     ',',
#     '1897–99',
#     ',',
#     'under',
#     'adrien',
#     'de',
#     'gerlache',
#     '.'],
#    ['traditionally',
#     ',',
#     'snk',
#     'operated',
#     'primarily',
#     'as',
#     'a',
#     'video',
#     'game',
#     'developer',
#     ',',
#     'publisher',
#     ',',
#     'and',
#     'hardware',
#     'manufacturer',
#     'with',
#     'a',
#     'focus',
#     'on',
#     'arcade',
#     'games',
#     ';',
#     'however',
#     ',',
#     'it',
#     'has',
#     'ventured',
#     'into',
#     'developing',
#     'console',
#     'and',
#     'pc',
#     'games',
#     '.'],
#    ['lang',
#     'was',
#     'later',
#     'lampooned',
#     'in',
#     'punch',
#     'for',
#     'a',
#     'lack',
#     'of',
#     '``',
#     'christian',
#     'charity',
#     "''",
#     '.'],
# ...
